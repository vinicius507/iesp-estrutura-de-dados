# %% [markdown]
# # Estruturas de dados

# %% [markdown]
# ## Lista Sequencial

# %%
import numpy as np
from numpy.random import f

class Listasequencial:

    def __init__(self, capacidade):
        self.capacidade = capacidade
        self.ultima_posicao = -1
        self.valores = np.empty(self.capacidade, dtype=int)

    def imprime(self):
        if self.ultima_posicao == -1:
            print('O vetor está vazio')
        else:
            for i in range(self.ultima_posicao + 1):
                print(i, ' - ', self.valores[i])

    def insere(self, valor):
        if self.ultima_posicao == self.capacidade - 1:
            print('Capacidade máxima atingida')
        else:
            self.ultima_posicao += 1
            self.valores[self.ultima_posicao] = valor

    def pesquisar(self, valor):
        for i in range(self.ultima_posicao + 1):
            if (valor==self.valores[i]):
                return i
        return -1

    def excluir(self, valor):
        posicao = self.pesquisar(valor)
        if posicao == -1:
            return -1
        else:
            for i in range(posicao, self.ultima_posicao):
                self.valores[i] = self.valores[i + 1]
        self.ultima_posicao -= 1

# %% [markdown]
# ## Ordenação

# %%
def bubble_sort(vetor):
  n=len(vetor)
  for i in range(n):
    for j in range(0,n-i-1):
      if vetor[j]>vetor[j+1]:
        aux=vetor[j]
        vetor[j]=vetor[j+1]
        vetor[j+1]=aux
  return (vetor)

def select_sort(vetor):
  n=len(vetor)
  for i in range(n):
    id_min=i
    for j in range(i+1,n):
      if vetor[id_min]>vetor[j]:
        id_min=j
    aux=vetor[i]
    vetor[i]=vetor[id_min]
    vetor[id_min]=aux
  return (vetor)

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

# %% [markdown]
# ## Pilha

# %%
class Pilha:

    def __init__(self):
        self.items = []

    def empilhar(self, item):
        self.items = self.items + [item]

    def desempilhar(self):
        if not self.is_vazia():
            item_removido = self.items[-1]
            self.items = self.items[:-1]
            return item_removido
        else:
            print("A pilha está vazia. Não é possível desempilhar.")

    def topo(self):
        if not self.is_vazia():
            return self.items[-1]
        else:
            print("A pilha está vazia. Não há topo para visualizar.")

    def is_vazia(self):
        return len(self.items) == 0

    def tamanho(self):
        return len(self.items)

    def imprimir(self):
        if not self.is_vazia():
            print("Itens da pilha:")
            for item in self.items:
                print(item)
        else:
            print("A pilha está vazia. Não há itens para imprimir.")

# %% [markdown]
# ## Fila

# %%
import numpy as np

class Fila:
    def __init__(self, capacidade):
        self.capacidade = capacidade
        self.inicio = 0
        self.final = -1
        self.numero_elementos = 0
        self.valores = np.empty(self.capacidade, dtype=int)

    def fila_vazia(self):
        return self.numero_elementos == 0

    def fila_cheia(self):
        return self.numero_elementos == self.capacidade

    def enfileirar(self, valor):
        if self.fila_cheia():
            print('A fila está cheia')
            return
        if self.final == self.capacidade - 1:
            self.final = -1
        self.final += 1
        self.valores[self.final] = valor
        self.numero_elementos += 1

    def desenfileirar(self):
        if self.fila_vazia():
            print('A fila já está vazia')
            return
        temp = self.valores[self.inicio]
        self.inicio += 1
        if self.inicio == self.capacidade - 1:
            self.inicio = 0
        else:
            self.numero_elementos -= 1
            return temp

    def primeiro(self):
        if self.fila_vazia():
            return -1
        else:
            return self.valores[self.inicio]

    def visualizar(self):
      print('Tamanho da Fila..: ', self.capacidade)
      print('Início da fila...: ', self.inicio)
      print('Final da fila....: ', self.final)
      print('Variável Nu. El..:', self.numero_elementos)

    def listageral(self):
      for i in range(self.capacidade):
        print(self.valores[i], end=' ')

# %% [markdown]
# # Importando dados do GitHub

# %%
import pandas as pd

# URL do arquivo csv no GitHub
url = 'https://raw.githubusercontent.com/nisston/disciplinaestruturadedados/main/data_temp.csv'

# Ler o arquivo CSV usando pandas e criando o objeto df1 (DataFrame)
df1 = pd.read_csv(url)

# %%
# Verificando o tamanho do DataFrame
df1.shape
# Out:
# (15907, 3)

# %%
# Exibir a estrutura do DataFrame
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15907 entries, 0 to 15906
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   key          15907 non-null  int64
#  1   time         15907 non-null  str
#  2   Temperature  13006 non-null  float64
# dtypes: float64(1), int64(1), str(1)
# memory usage: 372.9 KB

# %%
# Verificando se existe conteúdo em branco no dataframe
df1.isnull().sum()
# Out:
# key               0
# time              0
# Temperature    2901
# dtype: int64

# %%
# Apagando os conteúdos em branco no dataframe
df1.dropna(inplace=True, axis=0)

# %%
# Convertendo o tipo de dado e para uma lista
listaq1 = df1[:1000]['Temperature'].astype(int).to_list()

# %%
# Como separar os registros dependendo do Tipo de Prova
# Tipo A -    0 - 1000
# Tipo B - 1000 - 2000
# Tipo C - 2000 - 3000
# Tipo D - 3000 - 4000
# Tipo E - 4000 - 5000
# Tipo F - 5000 - 6000

# Pegando os dados para a Prova do Tipo A
df1[:1000]
# Out:
#      key                 time  Temperature
# 0      1  2019-05-03 11:16:18       1571.0
# 1      1  2019-05-03 11:25:53       1604.0
# 2      1  2019-05-03 11:29:11       1618.0
# 3      1  2019-05-03 11:30:01       1601.0
# 4      1  2019-05-03 11:30:39       1613.0
# ..   ...                  ...          ...
# 995  176  2019-05-09 21:43:56       1583.0
# 996  176  2019-05-09 21:50:34       1571.0
# 997  176  2019-05-09 21:52:59       1579.0
# 998  176  2019-05-09 21:54:54       1583.0
# 999  176  2019-05-09 21:55:36       1579.0
#
# [1000 rows x 3 columns]

# %%
# Carregando os dados
listatipoa = df1[:1000]['Temperature'].astype(int).to_list()
listatipob = df1[1000:2000]['Temperature'].astype(int).to_list()
listatipoc = df1[2000:3000]['Temperature'].astype(int).to_list()
listatipod = df1[3000:4000]['Temperature'].astype(int).to_list()
listatipoe = df1[4000:5000]['Temperature'].astype(int).to_list()
listatipof = df1[5000:6000]['Temperature'].astype(int).to_list()

# %% [markdown]
# # Faça aqui o código para responder as questões

# %%
def questao_01():
    listatipod = df1[3000:4000]['Temperature'].astype(int).to_list()
    lista = Listasequencial(150)

    for temperatura in listatipod[:150]:
        lista.insere(temperatura)

    print(f"A primeira temperatura é: {lista.valores[0]}")

questao_01()
# Out:
# A primeira temperatura é: 1582

# %%
def questao_02():
    listatipod = df1[3000:4000]['Temperature'].astype(int).to_list()
    listatipod = select_sort(listatipod)

    print(f"As cinco temperaturas mais altas são {listatipod[-5:]}")

questao_02()
# Out:
# As cinco temperaturas mais altas são [1654, 1657, 1661, 1673, 1675]

# %%
def questao_03():
    listatipod = df1[3000:4000]['Temperature'].astype(int).to_list()
    listatipod = bubble_sort(listatipod)

    print(f"As três temperaturas mais baixas são:")
    for idx in range(3):
        print(listatipod[idx])

questao_03()
# Out:
# As três temperaturas mais baixas são:
# 1530
# 1530
# 1531

# %%
def questao_04():
    pares, impares = 0, 0
    listatipod = df1[3000:4000]['Temperature'].astype(int).to_list()

    for temperatura in listatipod:
        if temperatura % 2 == 0:
            pares += 1
            continue
        impares += 1

    print(f"Pares: {pares} Impares: {impares}")

questao_04()
# Out:
# Pares: 500 Impares: 500

# %%
def questao_05():
    listatipod = df1[3000:4000]['Temperature'].astype(int).to_list()
    listatipod = select_sort(listatipod)
    temperatura_alvo = 1588

    contador = 0
    for temperatura in listatipod:
        if temperatura == temperatura_alvo:
            contador += 1

    print(f"Existem {contador} temperaturas {temperatura_alvo} na lista")

questao_05()
# Out:
# Existem 29 temperaturas 1588 na lista

# %%
def questao_06():
    listatipod = df1[3000:4000]['Temperature'].astype(int).to_list()
    listatipod = bubble_sort(listatipod)
    maximas = listatipod[-15:]
    media = sum(maximas) / 15

    print(f"A média das 15 temperaturas mais altas é: {media:.2f}")

questao_06()
# Out:
# A média das 15 temperaturas mais altas é: 1654.47

# %%
def questao_07():
    listatipod = df1[3000:4000]['Temperature'].astype(int).to_list()
    pilha = Pilha()

    for temperatura in listatipod[:150]:
        pilha.empilhar(temperatura)
    for _ in range(45):
        pilha.desempilhar()
    print(f"Topo da pilha: {pilha.topo()}")

questao_07()
# Out:
# Topo da pilha: 1617

# %%
def questao_08():
    listatipod = df1[3000:4000]['Temperature'].astype(int).to_list()
    pilha = Pilha()
    gerador_temperatura_par = (temp for temp in listatipod if temp % 2 == 0)

    for _ in range(50):
        temperatura = next(gerador_temperatura_par)
        pilha.empilhar(temperatura)
    for _ in range(25):
        pilha.desempilhar()
    print(f"Topo da pilha: {pilha.topo()}")

questao_08()
# Out:
#  temperatura: 1582
#  temperatura: 1594
#  temperatura: 1586
#  temperatura: 1572
#  temperatura: 1580
#  temperatura: 1592
#  temperatura: 1570
#  temperatura: 1588
#  temperatura: 1610
#  temperatura: 1560
#  temperatura: 1598
#  temperatura: 1588
#  temperatura: 1590
#  temperatura: 1600
#  temperatura: 1584
#  temperatura: 1604
#  temperatura: 1594
#  temperatura: 1594
#  temperatura: 1600
#  temperatura: 1588
#  temperatura: 1592
#  temperatura: 1614
#  temperatura: 1600
#  temperatura: 1606
#  temperatura: 1602
#  temperatura: 1604
#  temperatura: 1584
#  temperatura: 1606
#  temperatura: 1594
#  temperatura: 1596
#  temperatura: 1596
#  temperatura: 1632
#  temperatura: 1618
#  temperatura: 1622
#  temperatura: 1622
#  temperatura: 1590
#  temperatura: 1600
#  temperatura: 1600
#  temperatura: 1600
#  temperatura: 1588
#  temperatura: 1598
#  temperatura: 1606
#  temperatura: 1614
#  temperatura: 1618
#  temperatura: 1592
#  temperatura: 1564
#  temperatura: 1616
#  temperatura: 1588
#  temperatura: 1608
#  temperatura: 1602
# Topo da pilha: 1602

# %%
def questao_09():
    limite = 1550
    acima_do_limite = 0
    listatipod = df1[3000:4000]['Temperature'].astype(int).to_list()

    for temperatura in listatipod:
        if temperatura >= limite:
            acima_do_limite += 1
    print(f"Existem {acima_do_limite} temperaturas acima do limite de {limite}")

questao_09()
# Out:
# Existem 989 temperaturas acima do limite de 1550

# %%
def questao_10():
    listatipod = df1[3000:4000]['Temperature'].astype(int).to_list()
    listatipod = select_sort(listatipod)
    fila = Fila(250)

    for temperatura in listatipod[-250:]:
        fila.enfileirar(temperatura)
    for _ in range(50):
        fila.desenfileirar()
    print(f"Inicio da fila: {fila.primeiro()}")

questao_10()
# Out:
# Inicio da fila: 1606
